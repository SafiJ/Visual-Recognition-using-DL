# %% [markdown]
# function ClickConnect(){ console.log("Clicked on connect button"); document.querySelector("colab-connect-button").click() } setInterval(ClickConnect,60000)

# %%
import time
from google.colab import drive
drive.mount('/content/drive/')

# %cd /content/drive/MyDrive/VRDL/HW4
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/MyDrive/VRDL/HW4

# %%
# !git clone https://github.com/jiny2001/dcscn-super-resolution.git
# %cd dcscn-super-resolution
# Out:
# fatal: destination path 'dcscn-super-resolution' already exists and is not an empty directory.
# /content/drive/MyDrive/VRDL/HW4/dcscn-super-resolution

# %%
# !cp -r ../testing_lr_images data/

# %% [markdown]
# # Train

# %%
begin = time.time()
# !python3 train.py --dataset=training_hr_images_8 --scale=3 --layers=9 --filters=96 --filters_decay_gamma --self_ensemble=1
print(f"==========elapsed time: {time.time() - begin}==========")

# %% [markdown]
# # Generating

# %%
# !python3 evaluate.py --scale=3 --load_model_name=third --test_dataset=testing_lr_images

# %%
# !python3 evaluate.py --scale=3 --load_model_name=finalv2 --file=../testing_lr_images/01.png
# !python3 evaluate.py --scale=3 --load_model_name=finalv2 --file=../testing_lr_images/02.png
# !python3 evaluate.py --scale=3 --load_model_name=finalv2 --file=../testing_lr_images/03.png
# !python3 evaluate.py --scale=3 --load_model_name=finalv2 --file=../testing_lr_images/04.png
# !python3 evaluate.py --scale=3 --load_model_name=finalv2 --file=../testing_lr_images/05.png
# !python3 evaluate.py --scale=3 --load_model_name=finalv2 --file=../testing_lr_images/06.png
# !python3 evaluate.py --scale=3 --load_model_name=finalv2 --file=../testing_lr_images/07.png
# !python3 evaluate.py --scale=3 --load_model_name=finalv2 --file=../testing_lr_images/08.png
# !python3 evaluate.py --scale=3 --load_model_name=finalv2 --file=../testing_lr_images/09.png
# !python3 evaluate.py --scale=3 --load_model_name=finalv2 --file=../testing_lr_images/10.png
# !python3 evaluate.py --scale=3 --load_model_name=finalv2 --file=../testing_lr_images/11.png
# !python3 evaluate.py --scale=3 --load_model_name=finalv2 --file=../testing_lr_images/12.png
# !python3 evaluate.py --scale=3 --load_model_name=finalv2 --file=../testing_lr_images/13.png

# %% [markdown]
# # Data Augmentation

# %%
# !python3 augmentation.py --dataset=trianing_hr_images --augment_level=8
